# %% [markdown]
# <a href="https://colab.research.google.com/github/assu786/MACHINE-LEARNING/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
# !pip install ultralytics opencv-python matplotlib
# Out:
# ...
#   Using cached ultralytics-8.3.243-py3-none-any.whl.metadata (37 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.8 MB/s eta 0:00:00
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
#upload file to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d2b984c-1091-4062-a42e-57dc172bc06c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d2b984c-1091-4062-a42e-57dc172bc06c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#read the image with cv2 with image path
image_path=list(uploaded.keys())[0]
image=cv2.imread(image_path)

#convert BGR to RGB for display
img_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

#display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
#perform object detection
results=model(image)
# Out:
# 0: 448x640 2 chairs, 1 potted plant, 242.7ms
# Speed: 5.7ms preprocess, 242.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)

# %%
#draw bounding boxes on image
annotated_image = results[0].plot()

#convert BGR to RGB for display (plot() returns BGR)
annotated_image_rgb = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

#display the annotated image
plt.imshow(annotated_image_rgb)
plt.axis('off')
plt.show()
